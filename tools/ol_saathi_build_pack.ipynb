# %% [markdown]
# # Ol Saathi — build the Santali content pack
#
# Translates the app's 53 Hindi strings into Santali (Ol Chiki) using
# **AI4Bharat IndicTrans2**, the same model Bhashini serves for Hindi to Santali.
#
# **Runtime → Change runtime type → T4 GPU**, then **Runtime → Run all**.
# Takes about five minutes. The last cell downloads `pack.sat.json`.
#
# Drop that file into `app/src/main/assets/pack/` and the app's red
# SAMPLE DATA banner turns into a green Verified label by itself.

# %% [markdown]
# ## 1. Install

# %%
# !pip -q install transformers torch sentencepiece
# !pip -q install git+https://github.com/VarunGumma/IndicTransToolkit.git
print("installed")

# %% [markdown]
# ## 2. Load the model

# %%
import torch
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
from IndicTransToolkit.processor import IndicProcessor

MODEL = "Raghavan/indictrans2-en-indic-dist-200M"
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

tokenizer = AutoTokenizer.from_pretrained(MODEL, trust_remote_code=True)
model = AutoModelForSeq2SeqLM.from_pretrained(MODEL, trust_remote_code=True).to(DEVICE).eval()
ip = IndicProcessor(inference=True)

print("model :", MODEL)
print("device:", DEVICE)

# %% [markdown]
# ## 3. The strings
#
# Baked in, so there is nothing to upload.

# %%
ITEMS = [
 {
  "id": "p01",
  "hi": "नमस्ते बच्चों।",
  "en": "Hello children.",
  "nipun": "ROUTINE",
  "kind": "phrase"
 },
 {
  "id": "p02",
  "hi": "सब बैठ जाओ।",
  "en": "Everyone sit down.",
  "nipun": "ROUTINE",
  "kind": "phrase"
 },
 {
  "id": "p03",
  "hi": "आज हम क्या सीखेंगे?",
  "en": "What will we learn today?",
  "nipun": "ROUTINE",
  "kind": "phrase"
 },
 {
  "id": "p04",
  "hi": "कक्षा शुरू करते हैं।",
  "en": "Let us begin the class.",
  "nipun": "ROUTINE",
  "kind": "phrase"
 },
 {
  "id": "p05",
  "hi": "अब छुट्टी का समय है।",
  "en": "It is time to go home.",
  "nipun": "ROUTINE",
  "kind": "phrase"
 },
 {
  "id": "p06",
  "hi": "किताब खोलो।",
  "en": "Open your book.",
  "nipun": "ROUTINE",
  "kind": "phrase"
 },
 {
  "id": "p07",
  "hi": "किताब बंद करो।",
  "en": "Close your book.",
  "nipun": "ROUTINE",
  "kind": "phrase"
 },
 {
  "id": "p08",
  "hi": "पेंसिल उठाओ।",
  "en": "Pick up your pencil.",
  "nipun": "ROUTINE",
  "kind": "phrase"
 },
 {
  "id": "p09",
  "hi": "मेरे पीछे दोहराओ।",
  "en": "Repeat after me.",
  "nipun": "FL-OL",
  "kind": "phrase"
 },
 {
  "id": "p10",
  "hi": "ध्यान से सुनो।",
  "en": "Listen carefully.",
  "nipun": "FL-OL",
  "kind": "phrase"
 },
 {
  "id": "p11",
  "hi": "ज़ोर से बोलो।",
  "en": "Speak loudly.",
  "nipun": "FL-OL",
  "kind": "phrase"
 },
 {
  "id": "p12",
  "hi": "अपना नाम लिखो।",
  "en": "Write your name.",
  "nipun": "FL-WR",
  "kind": "phrase"
 },
 {
  "id": "p13",
  "hi": "चित्र देखो।",
  "en": "Look at the picture.",
  "nipun": "FL-RD",
  "kind": "phrase"
 },
 {
  "id": "p14",
  "hi": "हाथ उठाओ।",
  "en": "Raise your hand.",
  "nipun": "ROUTINE",
  "kind": "phrase"
 },
 {
  "id": "p15",
  "hi": "शांत हो जाओ।",
  "en": "Please be quiet.",
  "nipun": "ROUTINE",
  "kind": "phrase"
 },
 {
  "id": "p16",
  "hi": "जोड़ी में बैठो।",
  "en": "Sit in pairs.",
  "nipun": "ROUTINE",
  "kind": "phrase"
 },
 {
  "id": "p17",
  "hi": "एक बार फिर कोशिश करो।",
  "en": "Try once more.",
  "nipun": "ROUTINE",
  "kind": "phrase"
 },
 {
  "id": "p18",
  "hi": "बहुत अच्छा!",
  "en": "Very good!",
  "nipun": "ROUTINE",
  "kind": "phrase"
 },
 {
  "id": "p19",
  "hi": "शाबाश!",
  "en": "Well done!",
  "nipun": "ROUTINE",
  "kind": "phrase"
 },
 {
  "id": "p20",
  "hi": "सही जवाब।",
  "en": "Correct answer.",
  "nipun": "ROUTINE",
  "kind": "phrase"
 },
 {
  "id": "p21",
  "hi": "कोई बात नहीं।",
  "en": "Never mind, it is all right.",
  "nipun": "ROUTINE",
  "kind": "phrase"
 },
 {
  "id": "p22",
  "hi": "क्या तुम समझ गए?",
  "en": "Did you understand?",
  "nipun": "FL-OL",
  "kind": "phrase"
 },
 {
  "id": "p23",
  "hi": "यह क्या है?",
  "en": "What is this?",
  "nipun": "FL-OL",
  "kind": "phrase"
 },
 {
  "id": "p24",
  "hi": "तुम्हारा नाम क्या है?",
  "en": "What is your name?",
  "nipun": "FL-OL",
  "kind": "phrase"
 },
 {
  "id": "p25",
  "hi": "कौन बताएगा?",
  "en": "Who will tell me?",
  "nipun": "FL-OL",
  "kind": "phrase"
 },
 {
  "id": "p26",
  "hi": "क्या तुम्हें कोई सवाल है?",
  "en": "Do you have a question?",
  "nipun": "FL-OL",
  "kind": "phrase"
 },
 {
  "id": "p27",
  "hi": "एक से दस तक गिनो।",
  "en": "Count from one to ten.",
  "nipun": "FN-NS",
  "kind": "phrase"
 },
 {
  "id": "p28",
  "hi": "कितने हैं?",
  "en": "How many are there?",
  "nipun": "FN-NS",
  "kind": "phrase"
 },
 {
  "id": "p29",
  "hi": "दो और तीन कितने होते हैं?",
  "en": "What is two plus three?",
  "nipun": "FN-OP",
  "kind": "phrase"
 },
 {
  "id": "p30",
  "hi": "कौन सी संख्या बड़ी है?",
  "en": "Which number is bigger?",
  "nipun": "FN-NS",
  "kind": "phrase"
 },
 {
  "id": "p31",
  "hi": "इन्हें गिनकर बताओ।",
  "en": "Count these and tell me.",
  "nipun": "FN-NS",
  "kind": "phrase"
 },
 {
  "id": "p32",
  "hi": "यह अक्षर पढ़ो।",
  "en": "Read this letter.",
  "nipun": "FL-RD",
  "kind": "phrase"
 },
 {
  "id": "p33",
  "hi": "यह शब्द पढ़ो।",
  "en": "Read this word.",
  "nipun": "FL-RD",
  "kind": "phrase"
 },
 {
  "id": "p34",
  "hi": "इस शब्द की पहली ध्वनि क्या है?",
  "en": "What is the first sound in this word?",
  "nipun": "FL-RD",
  "kind": "phrase"
 },
 {
  "id": "p35",
  "hi": "कहानी सुनो।",
  "en": "Listen to the story.",
  "nipun": "FL-OL",
  "kind": "phrase"
 },
 {
  "id": "p36",
  "hi": "अपनी भाषा में बताओ।",
  "en": "Tell me in your own language.",
  "nipun": "FL-OL",
  "kind": "phrase"
 },
 {
  "id": "p37",
  "hi": "यह वाक्य दोहराओ।",
  "en": "Repeat this sentence.",
  "nipun": "FL-OL",
  "kind": "phrase"
 },
 {
  "id": "p38",
  "hi": "क्या तुम ठीक हो?",
  "en": "Are you all right?",
  "nipun": "ROUTINE",
  "kind": "phrase"
 },
 {
  "id": "p39",
  "hi": "पानी पी लो।",
  "en": "Drink some water.",
  "nipun": "ROUTINE",
  "kind": "phrase"
 },
 {
  "id": "p40",
  "hi": "घर पर अभ्यास करना।",
  "en": "Practise at home.",
  "nipun": "ROUTINE",
  "kind": "phrase"
 },
 {
  "id": "neema-dadi.l1",
  "hi": "नीमा दोपहर में दो बजे स्कूल से लौटती है।",
  "en": "Neema comes home from school at two in the afternoon.",
  "nipun": "FL-RD",
  "kind": "lesson",
  "lesson": "neema-dadi",
  "image": "school-return"
 },
 {
  "id": "neema-dadi.l2",
  "hi": "इस समय घर पर सिर्फ़ दादी होती हैं।",
  "en": "At that time only her grandmother is at home.",
  "nipun": "FL-RD",
  "kind": "lesson",
  "lesson": "neema-dadi",
  "image": "grandmother"
 },
 {
  "id": "neema-dadi.l3",
  "hi": "दादी कहीं नहीं आती-जाती हैं।",
  "en": "Grandmother does not go anywhere.",
  "nipun": "FL-RD",
  "kind": "lesson",
  "lesson": "neema-dadi",
  "image": "sitting"
 },
 {
  "id": "neema-dadi.l4",
  "hi": "उनके घुटनों में दर्द रहता है।",
  "en": "Her knees hurt.",
  "nipun": "FL-RD",
  "kind": "lesson",
  "lesson": "neema-dadi",
  "image": "knees"
 },
 {
  "id": "neema-dadi.l5",
  "hi": "उन्हें नीमा का बहुत इंतज़ार होता है।",
  "en": "She waits eagerly for Neema.",
  "nipun": "FL-RD",
  "kind": "lesson",
  "lesson": "neema-dadi",
  "image": "waiting"
 },
 {
  "id": "neema-dadi.l6",
  "hi": "नीमा रोज़ खाना खाते-खाते स्कूल की बातें सुनाती है।",
  "en": "Every day, while eating, Neema tells her about school.",
  "nipun": "FL-RD",
  "kind": "lesson",
  "lesson": "neema-dadi",
  "image": "eating-talking"
 },
 {
  "id": "neema-dadi.l7",
  "hi": "शाम को नीमा खेलने जाती है।",
  "en": "In the evening Neema goes out to play.",
  "nipun": "FL-RD",
  "kind": "lesson",
  "lesson": "neema-dadi",
  "image": "playing"
 },
 {
  "id": "neema-dadi.l8",
  "hi": "एक दिन दादी बोलीं, मेरा समय नहीं कटता।",
  "en": "One day grandmother said, my time does not pass.",
  "nipun": "FL-RD",
  "kind": "lesson",
  "lesson": "neema-dadi",
  "image": "lonely"
 },
 {
  "id": "neema-dadi.l9",
  "hi": "नीमा दौड़कर दादी की चप्पलें ले आई।",
  "en": "Neema ran and fetched grandmother's slippers.",
  "nipun": "FL-RD",
  "kind": "lesson",
  "lesson": "neema-dadi",
  "image": "slippers"
 },
 {
  "id": "neema-dadi.l10",
  "hi": "फिर वे दोनों खेल के मैदान की ओर चल पड़े।",
  "en": "Then the two of them set off towards the playground.",
  "nipun": "FL-RD",
  "kind": "lesson",
  "lesson": "neema-dadi",
  "image": "walking-together"
 },
 {
  "id": "neema-dadi.c1",
  "hi": "इस समय घर पर कौन होता है?",
  "en": "Who is at home at that time?",
  "nipun": "FL-OL",
  "kind": "check",
  "lesson": "neema-dadi"
 },
 {
  "id": "neema-dadi.c2",
  "hi": "दादी के कहाँ दर्द रहता है?",
  "en": "Where does grandmother have pain?",
  "nipun": "FL-OL",
  "kind": "check",
  "lesson": "neema-dadi"
 },
 {
  "id": "neema-dadi.c3",
  "hi": "अंत में नीमा और दादी कहाँ गईं?",
  "en": "Where did Neema and grandmother go at the end?",
  "nipun": "FL-OL",
  "kind": "check",
  "lesson": "neema-dadi"
 }
]

print(len(ITEMS), "strings")

# %% [markdown]
# ## 4. Translate to Santali

# %%
SRC, TGT = "eng_Latn", "sat_Olck"

def translate(sentences, batch_size=8):
    out = []
    for i in range(0, len(sentences), batch_size):
        chunk = sentences[i:i + batch_size]
        batch = ip.preprocess_batch(chunk, src_lang=SRC, tgt_lang=TGT)
        enc = tokenizer(batch, truncation=True, padding=True,
                        max_length=256, return_tensors="pt").to(DEVICE)
        with torch.no_grad():
            gen = model.generate(**enc, num_beams=5, max_length=256,
                                 min_length=0, num_return_sequences=1)
        dec = tokenizer.batch_decode(gen, skip_special_tokens=True)
        out += ip.postprocess_batch(dec, lang=TGT)
        print(f"  {min(i + batch_size, len(sentences))}/{len(sentences)}", end="\r")
    return out

# We pivot through the English we wrote by hand rather than through a
# machine translation of the Hindi. One model hop from clean human text
# beats two hops with compounding error.
targets = translate([it["en"] for it in ITEMS])
print("\ndone:", len(targets))

# %% [markdown]
# ## 5. Check it before trusting it
#
# The last pack that reached this project was invented, passed every structural
# test, and would have been shown to a Jharkhand judge under a green Verified
# label. These checks are the ones that would have caught it.
#
# The transliteration check is the important one. If the Hindi to Santali
# character ratio sits near 1.0 across the board, the model has respelled the
# Hindi rather than translated it, and the output is worthless.

# %%
import unicodedata as ud, statistics

OLCK_LETTER = range(0x1C5A, 0x1C78)
OLCK_DIGIT  = range(0x1C50, 0x1C5A)
DEVA        = range(0x0900, 0x0980)

def has(s, rng): return any(ord(c) in rng for c in s)

digits   = [(i["hi"], t) for i, t in zip(ITEMS, targets) if has(t, OLCK_DIGIT)]
no_olck  = [(i["hi"], t) for i, t in zip(ITEMS, targets) if not has(t, OLCK_LETTER)]
deva     = [(i["hi"], t) for i, t in zip(ITEMS, targets) if has(t, DEVA)]

seen, collisions = {}, []
for i, t in zip(ITEMS, targets):
    if t in seen and seen[t] != i["hi"]:
        collisions.append((seen[t], i["hi"], t))
    seen[t] = i["hi"]

ratios = [len(t) / max(1, len(i["en"])) for i, t in zip(ITEMS, targets)]
median_ratio = statistics.median(ratios)

print(f"Ol Chiki digits inside words : {len(digits)}   (want 0)")
print(f"targets with no Ol Chiki     : {len(no_olck)}  (want 0)")
print(f"targets containing Devanagari: {len(deva)}     (want 0)")
print(f"distinct sources colliding   : {len(collisions)} (want 0)")
print(f"median en->sat char ratio    : {median_ratio:.2f}")
print()
if 0.95 < median_ratio < 1.20:
    print("WARNING: ratio near 1.0 suggests transliteration, not translation.")
    print("Read a few pairs below before using this pack.")
else:
    print("Ratio looks like real translation rather than character substitution.")

print("\nFirst eight pairs, read them:")
for i, t in list(zip(ITEMS, targets))[:8]:
    print(f"  {i['hi']}")
    print(f"    -> {t}")

# %% [markdown]
# ## 6. Write the pack

# %%
import json, datetime

pack = {
    "language": "sat",
    "source": "hi",
    "generated": datetime.datetime.utcnow().isoformat() + "Z",
    "provenance": {
        "translationService": MODEL,
        "ttsService": None,
        "platform": "AI4Bharat IndicTrans2 (ungated MIT mirror). Same model family Bhashini serves for this language pair.",
        "pivot": "Human-authored English, then machine translated to Santali",
        "note": "Machine translation by IndicTrans2 from human-written English. Not checked by a Santali speaker.",
    },
    "entries": {},
}

now = pack["generated"]
for it, tgt in zip(ITEMS, targets):
    e = {
        "source": it["hi"], "target": tgt, "en": it["en"],
        "nipun": it["nipun"], "kind": it["kind"],
        "service": MODEL, "at": now,
    }
    if it.get("lesson"): e["lesson"] = it["lesson"]
    if it.get("image"):  e["image"] = it["image"]
    pack["entries"][it["id"]] = e

with open("pack.sat.json", "w", encoding="utf-8") as f:
    json.dump(pack, f, ensure_ascii=False, indent=2)

print("wrote pack.sat.json with", len(pack["entries"]), "entries")

# %% [markdown]
# ## 7. Download
#
# Then put it in `app/src/main/assets/pack/pack.sat.json`, replacing the sample.
#
# There is no audio in this pack, because Santali text to speech exists only on
# Bhashini. Text, worksheets and offline operation all work without it. Audio
# arrives when the Bhashini account is approved.

# %%
from google.colab import files
files.download("pack.sat.json")
